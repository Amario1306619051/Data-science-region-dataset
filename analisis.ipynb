# %% [markdown]
# ## Panggil library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
#import dataset
dataset = pd.read_csv('/Users/amariofausta/Downloads/Test data Scientist - Region Dataset 5/data survey.csv')
dataset
# Out:
#                          id                  name   age    age_range  \
# 0       id_4100001227501134                Sultan   NaN          NaN
# 1       id_4100001746833302          Arief Rahman  23.0  22-30 tahun
# 2       id_4100001746833302          Arief Rahman  23.0  22-30 tahun
# 3       id_4100001746833302          Arief Rahman  23.0  22-30 tahun
# 4       id_4100001746833302          Arief Rahman  23.0  22-30 tahun
# ...                     ...                   ...   ...          ...
# 425327  id_4100026362102517          Elcha Borreg   NaN          NaN
# 425328  id_4100026474571982            Nda Ridwan   NaN          NaN
# 425329  id_4100026474571982            Nda Ridwan   NaN          NaN
# 425330  id_4100029181741974  Marlin Fitri Wahyuni  25.0  22-30 tahun
# 425331  id_4100029181741974  Marlin Fitri Wahyuni  25.0  22-30 tahun
#
#                   province         city  gender    interest interest_detail
# ...

# %%
#meliihat info dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425332 entries, 0 to 425331
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               425332 non-null  object
#  1   name             425329 non-null  object
#  2   age              265035 non-null  float64
#  3   age_range        265035 non-null  object
#  4   province         317301 non-null  object
#  5   city             317301 non-null  object
#  6   gender           374451 non-null  object
#  7   interest         425332 non-null  object
#  8   interest_detail  122838 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 29.2+ MB

# %% [markdown]
# ### Informasi DataFrame
#
# Ini adalah informasi rinci tentang DataFrame yang diberikan.
#
# - **Tipe Data**: `pandas.core.frame.DataFrame`
#
# - **Indeks**: RangeIndex dengan 425,332 entri dari 0 hingga 425,331.
#
# - **Kolom Data (Total 9 Kolom)**:
#   1. `id`: Terdapat 425,332 entri non-null dengan tipe data 'object'.
#   2. `name`: Terdapat 425,329 entri non-null dengan tipe data 'object'.
#   3. `age`: Terdapat 265,035 entri non-null dengan tipe data 'float64'.
#   4. `age_range`: Terdapat 265,035 entri non-null dengan tipe data 'object'.
#   5. `province`: Terdapat 317,301 entri non-null dengan tipe data 'object'.
#   6. `city`: Terdapat 317,301 entri non-null dengan tipe data 'object'.
#   7. `gender`: Terdapat 374,451 entri non-null dengan tipe data 'object'.
#   8. `interest`: Terdapat 425,332 entri non-null dengan tipe data 'object'.
#   9. `interest_detail`: Terdapat 122,838 entri non-null dengan tipe data 'object'.
#
# Ini adalah ringkasan tentang DataFrame yang menggambarkan tipe data, jumlah entri, dan data yang hilang dalam setiap kolom.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Menghitung Jumlah Data yang Hilang dalam Setiap Kolom
#
# ```python
# # Menghitung jumlah data yang hilang dalam setiap kolom
# missing_data = dataset.isna().sum()
#
# # Menampilkan hasil
# print(missing_data)
# ```
#
# Deskripsi Singkat:
# Kode ini digunakan untuk menghitung jumlah data yang hilang (missing data) dalam setiap kolom (atribut) dari suatu dataset. Langkah-langkahnya adalah sebagai berikut:
#
# 1. `missing_data = dataset.isna().sum()`: Pada baris ini, kita menggunakan `.isna()` untuk mengidentifikasi nilai-nilai yang hilang dalam dataset. Hasilnya adalah DataFrame baru yang berisi `True` untuk setiap sel yang memiliki data yang hilang, dan `False` untuk yang lainnya. Kemudian, kita menggunakan `.sum()` pada DataFrame ini untuk menghitung jumlah nilai `True` dalam setiap kolom, sehingga kita mendapatkan jumlah data yang hilang dalam setiap kolom.
#
# 2. `print(missing_data)`: Baris ini digunakan untuk mencetak hasil perhitungan jumlah data yang hilang dalam setiap kolom ke layar atau konsol.
#
# Dengan kode ini, Anda akan mendapatkan output berupa daftar atau Series yang menunjukkan jumlah data yang hilang dalam setiap kolom dari dataset yang digunakan. Informasi ini penting untuk menganalisis sejauh mana data yang hilang dalam dataset dan untuk memutuskan langkah-langkah selanjutnya dalam pengolahan data atau pemenuhan data yang hilang.
# ```

# %%
# Menghitung jumlah data yang hilang dalam setiap kolom
missing_data = dataset.isna().sum()

# Menampilkan hasil
print(missing_data)
# Out:
# id                      0
# name                    3
# age                160297
# age_range          160297
# province           108031
# city               108031
# gender              50881
# interest                0
# interest_detail    302494
# dtype: int64

# %% [markdown]
# ## Hasil dari perhitungan jumlah data yang hilang dalam setiap kolom pada dataset adalah sebagai berikut:
#
# - Kolom "id" tidak memiliki data yang hilang (jumlah data yang hilang = 0).
# - Kolom "name" memiliki 3 data yang hilang.
# - Kolom "age" memiliki 160,297 data yang hilang.
# - Kolom "age_range" juga memiliki 160,297 data yang hilang.
# - Kolom "province" memiliki 108,031 data yang hilang.
# - Kolom "city" juga memiliki 108,031 data yang hilang.
# - Kolom "gender" memiliki 50,881 data yang hilang.
# - Kolom "interest" tidak memiliki data yang hilang (jumlah data yang hilang = 0).
# - Kolom "interest_detail" memiliki 302,494 data yang hilang.
#
# Informasi ini sangat berguna untuk menentukan langkah-langkah selanjutnya dalam pemrosesan data, seperti penghapusan data yang hilang, pengisian data yang hilang, atau analisis lebih lanjut terkait dengan kolom-kolom tertentu.

# %% [markdown]
# berdasarkan data interset_detail dapat diwakili oleh interest
# age sudah diwakili oleh age range

# %%
# Mengambil subset dataset tanpa kolom "interest_detail"
datasetInterestDetail = dataset[['interest','interest_detail']]
dataset = dataset[['id', 'name','age','age_range', 'province', 'city', 'gender', 'interest']]

# %%
dataset = dataset.dropna()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209558 entries, 5 to 425331
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         209558 non-null  object
#  1   name       209558 non-null  object
#  2   age        209558 non-null  float64
#  3   age_range  209558 non-null  object
#  4   province   209558 non-null  object
#  5   city       209558 non-null  object
#  6   gender     209558 non-null  object
#  7   interest   209558 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 14.4+ MB

# %%
#menghapus duplikasi
dataset = dataset.drop_duplicates(subset='id')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80214 entries, 5 to 425330
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         80214 non-null  object
#  1   name       80214 non-null  object
#  2   age        80214 non-null  float64
#  3   age_range  80214 non-null  object
#  4   province   80214 non-null  object
#  5   city       80214 non-null  object
#  6   gender     80214 non-null  object
#  7   interest   80214 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 5.5+ MB

# %%
# Menghitung jumlah masing-masing kategori
gender_counts = dataset['gender'].value_counts()

# Membuat pie chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Distribusi Gender')
plt.axis('equal')  # Agar diagram lingkaran terlihat bulat
plt.show()

# %%
# Membaca dataset (misalnya, dataset disimpan dalam variabel df)
age_range = dataset['age_range']

# Membuat plot diagram batang
sns.countplot(data=dataset, x='age_range')
plt.title('Distribusi Age Range')
plt.xticks(rotation=45)  # Untuk mengatur label sumbu x
plt.show()

# %%
#plot goup city, dan lokasi
grouped_data = dataset.groupby(['province', 'city'])
result = grouped_data.size().reset_index(name='count')
result
# Out:
#            province              city  count
# 0              Aceh              Aceh    143
# 1              Aceh        Aceh Barat      1
# 2              Aceh   Aceh Barat Daya      1
# 3              Aceh        Aceh Besar      2
# 4              Aceh         Aceh Jaya      7
# ..              ...               ...    ...
# 379  Sumatera Utara        Simalungun     42
# 380  Sumatera Utara    Sumatera Utara    504
# 381  Sumatera Utara  Tapanuli Selatan      3
# 382  Sumatera Utara   Tapanuli Tengah      6
# 383  Sumatera Utara    Tapanuli Utara      8
#
# [384 rows x 3 columns]

# %%
# Menghitung jumlah masing-masing kota dalam setiap provinsi
city_counts = dataset.groupby(['province', 'city']).size().unstack().fillna(0)

for location in city_counts.index:
    plt.figure(figsize=(6, 6))
    pie_data = city_counts.loc[location]
    top_cities = pie_data.nlargest(5)  # Menampilkan hanya 5 kota dengan frekuensi tertinggi
    other_cities = pie_data.sum() - top_cities.sum()
    pie_data = top_cities.append(pd.Series([other_cities], index=['Others']))

    # Membuat pie chart
    plt.pie(pie_data, autopct='%1.1f%%', startangle=140)
    plt.title(f'Distribusi Kota di {location}')
    plt.axis('equal')  # Agar diagram lingkaran terlihat bulat

    # Menambahkan legend di luar pie chart
    plt.legend(title='Kota', labels=pie_data.index, loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
    plt.show()
# Out:
# /var/folders/2p/8rq7kl1j27nftt5zfzsg8tyc0000gn/T/ipykernel_91661/1049772158.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pie_data = top_cities.append(pd.Series([other_cities], index=['Others']))
# /var/folders/2p/8rq7kl1j27nftt5zfzsg8tyc0000gn/T/ipykernel_91661/1049772158.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pie_data = top_cities.append(pd.Series([other_cities], index=['Others']))
# /var/folders/2p/8rq7kl1j27nftt5zfzsg8tyc0000gn/T/ipykernel_91661/1049772158.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pie_data = top_cities.append(pd.Series([other_cities], index=['Others']))
# ...

# %%
dataset1 = dataset[(dataset['province'] == 'Jawa Tengah') | (dataset['province'] == 'Jawa Barat')]

# %%
# Filter data untuk Jawa Barat
jabar_df = dataset1[dataset1['province'] == 'Jawa Barat']

# Menghitung distribusi gender di Jawa Barat
gender_counts = jabar_df['gender'].value_counts()

# Membuat pie chart untuk distribusi gender
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Gender di Jawa Barat')
plt.axis('equal')
plt.show()

# Menghitung distribusi Age Range di Jawa Barat
age_range_counts = jabar_df['age_range'].value_counts() 

# Membuat pie chart untuk distribusi Age Range
plt.figure(figsize=(8, 8))
_, _, autotexts = plt.pie(age_range_counts, labels=age_range_counts.index, autopct='%1.1f%%', startangle=140)

# Menambahkan legend dengan label yang sesuai
plt.title('Distribusi Age Range di Jawa Barat')
plt.axis('equal')

# Menampilkan legend di luar pie chart
legend_labels = age_range_counts.index
plt.legend(legend_labels, title='Age Range', loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Menambahkan label persentase di sekitar pie chart
for autotext in autotexts:
    autotext.set_size(12)
    autotext.set_color('white')

plt.show()


# Visualisasi Interest di Jawa Barat (contoh word cloud)

interest_text_jabar = ' '.join(jabar_df['interest'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(interest_text_jabar)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Minat Umum di Jawa Barat')
plt.axis('off')
plt.show()

# %%
# Filter data untuk Jawa Barat
jabar_df = dataset[dataset['province'] == 'Jawa Barat']

# Menghitung jumlah masing-masing minat
interest_counts_jabar = jabar_df['interest'].value_counts()

# Menampilkan jumlah masing-masing minat
print(interest_counts_jabar)
# Out:
# Pakaian           3441
# Kuliner           2730
# Fotografi         2673
# Pecinta Burung    2558
# Sepatu            2020
# Berkebun           910
# Memancing          255
# Memasak            209
# Aksesories         135
# Koleksi            120
# Dasi               102
# Topi                93
# Tas                 89
# Musik               71
# Menjahit            66
# Membaca             64
# Kecantikan          63
# Komik               23
# Perhiasan           16
# Fitness              5
# Menari               3
# Sandal               1
# Name: interest, dtype: int64

# %%
# Filter data untuk Jawa Tengah
jateng_df = dataset1[dataset1['province'] == 'Jawa Tengah']

# Menghitung distribusi gender di Jawa Barat
gender_counts = jateng_df['gender'].value_counts()

# Membuat pie chart untuk distribusi gender
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribusi Gender di Jawa Tengah')
plt.axis('equal')
plt.show()

# Menghitung distribusi Age Range di Jawa Barat
age_range_counts = jateng_df['age_range'].value_counts() 

# Membuat pie chart untuk distribusi Age Range
plt.figure(figsize=(8, 8))
_, _, autotexts = plt.pie(age_range_counts, labels=age_range_counts.index, autopct='%1.1f%%', startangle=140)

# Menambahkan legend dengan label yang sesuai
plt.title('Distribusi Age Range di Jawa Tengah')
plt.axis('equal')

# Menampilkan legend di luar pie chart
legend_labels = age_range_counts.index
plt.legend(legend_labels, title='Age Range', loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Visualisasi Interest di Jawa Tengah (contoh word cloud)
interest_text_jateng = ' '.join(jateng_df['interest'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(interest_text_jateng)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Minat Umum di Jawa Tengah')
plt.axis('off')
plt.show()

# %%
# Filter data untuk Jawa Tengah
jateng_df = dataset[dataset['province'] == 'Jawa Tengah']

# Menghitung jumlah masing-masing minat
interest_counts_jateng = jateng_df['interest'].value_counts()

# Menampilkan jumlah masing-masing minat
print(interest_counts_jateng)
# Out:
# Kuliner           4011
# Pecinta Burung    3821
# Fotografi         3034
# Pakaian           1872
# Berkebun          1301
# Sepatu             688
# Memancing          548
# Dasi               283
# Memasak            156
# Koleksi            132
# Aksesories         110
# Membaca             90
# Tas                 79
# Kecantikan          77
# Menjahit            69
# Musik               57
# Komik               10
# Perhiasan            5
# Fitness              5
# Topi                 3
# kebaya               2
# Menari               1
# Name: interest, dtype: int64

# %%
#mengubah category

#memanfaatkan fungsi deh
def categorize_age(age):
    if 10 <= age < 25:
        return 'Gen Z'
    elif 25 <= age < 40:
        return 'Gen Millennial'
    elif 40 <= age < 60:
        return 'Gen X'
    elif age >= 60:
        return 'Baby Boomers'
    elif age < 10:
        return 'Gen Alpha'
    else:
        return 'Unknown'


#menambahkan semua kolom
dataset['age_category'] = dataset['age'].apply(categorize_age)
age_category_counts = dataset['age_category'].value_counts()

# %%
print(age_category_counts)
# Out:
# Gen Z             51149
# Gen Millennial    26695
# Gen X              2033
# Baby Boomers        333
# Gen Alpha             4
# Name: age_category, dtype: int64

# %%
# Menghitung jumlah kategori usia
age_category_counts = dataset['age_category'].value_counts()

# Membuat pie chart untuk distribusi kategori usia
plt.figure(figsize=(8, 8))
plt.pie(age_category_counts, autopct='%1.1f%%', startangle=140)

# Menambahkan legend dengan label yang sesuai
plt.title('Distribusi Kategori Usia')
plt.axis('equal')

# Menampilkan legend di luar pie chart
legend_labels = age_category_counts.index
plt.legend(legend_labels, title='Kategori Usia', loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %%
jatim = dataset[(dataset['province'] == 'Jawa Timur') | (dataset['province'] == 'Jawa Timur')]
jatim = jatim[(dataset['age_category'] == 'Gen Millennial')]
# Out:
# /var/folders/2p/8rq7kl1j27nftt5zfzsg8tyc0000gn/T/ipykernel_91661/1409208003.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jatim = jatim[(dataset['age_category'] == 'Gen Millennial')]

# %%
# Visualisasi Interest di Jawa Tengah (contoh word cloud)
interest_text_jatim = ' '.join(jatim['interest'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(interest_text_jateng)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Minat Umum di Jawa Timur')
plt.axis('off')
plt.show()

# %%
# Filter data untuk Jawa Tengah
jateng = dataset[dataset['province'] == 'Jawa Tengah']

# Menghitung jumlah masing-masing minat
interest_counts = jateng['interest'].value_counts()

# Menampilkan jumlah masing-masing minat
print(interest_counts)
# Out:
# Kuliner           4011
# Pecinta Burung    3821
# Fotografi         3034
# Pakaian           1872
# Berkebun          1301
# Sepatu             688
# Memancing          548
# Dasi               283
# Memasak            156
# Koleksi            132
# Aksesories         110
# Membaca             90
# Tas                 79
# Kecantikan          77
# Menjahit            69
# Musik               57
# Komik               10
# Perhiasan            5
# Fitness              5
# Topi                 3
# kebaya               2
# Menari               1
# Name: interest, dtype: int64
